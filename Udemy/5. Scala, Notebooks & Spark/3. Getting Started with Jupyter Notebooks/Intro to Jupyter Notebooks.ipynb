# %%
9 + 9
# Out:
# 18

# %%
x = 10
if x > 10:
    print("Greater than 10!")
else:
    print("Less than or Equal to 10!")
# Out:
# Less than or Equal to 10!

# %%
import pandas as pd
df = pd.read_csv("ActivityLog01.csv")
df
# Out:
#                              Correlationid                    Operationname  \
# 0     c5cf5ce4-d26f-4910-bc9d-715a40620256           Delete Storage Account
# 1     c5cf5ce4-d26f-4910-bc9d-715a40620256                   Delete website
# 2     c5cf5ce4-d26f-4910-bc9d-715a40620256                 Delete Namespace
# 3     c5cf5ce4-d26f-4910-bc9d-715a40620256                   Delete website
# 4     c5cf5ce4-d26f-4910-bc9d-715a40620256              Delete SQL database
# ...                                    ...                              ...
# 5431  42286778-19ba-4a47-91da-ae457c4ca1f4                   Actionrequired
# 5432  8dd1e5ef-2dd6-480e-a6bc-fa707decc633  New recommendation is available
# 5433  82bd2576-87da-4ebf-ad6d-2047ccbd6bef  New recommendation is available
# 5434  d3068d15-4b42-4ce8-9327-9430fb57c543           Delete NotebookProxies
# 5435  d3068d15-4b42-4ce8-9327-9430fb57c543           Delete NotebookProxies
#
# ...
